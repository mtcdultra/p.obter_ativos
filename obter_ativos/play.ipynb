# %%
import retornar_ativos as ra
import yfinance as yf

ativos = ra.retornar_acoes_existentes()

ativos = ativos + ".SA"

#for i in ra.retornar_acoes_existentes():

    #ativo = yf.Ticker(i)
 #   print(i+".SA")

# %%
import requests
from bs4 import BeautifulSoup
import yfinance as yf

def retornar_acoes_existentes():

    page = requests.get("https://www.infomoney.com.br/cotacoes/empresas-b3/")
    soup = BeautifulSoup(page.content, "html.parser")
    lista_ativo = soup.find(class_="col-md-9 col-lg-8 col-xl-6 m-sm-auto m-lg-0 article-content")
    codigo_ativo = lista_ativo.find_all("td", class_="strong")

    resultados = []

    for codigos_ativos in codigo_ativo:

        if ( codigos_ativos.text.strip()[-1:] == "F" ) or ( codigos_ativos.text.strip() == "" ) : continue

        resultados.append(codigos_ativos.text.strip()+".SA")

    return resultados

def retornar_fiis_existentes():

    page = requests.get("https://www.fundsexplorer.com.br/funds")
    soup = BeautifulSoup(page.content, "html.parser")
    lista_ativo = soup.find(id="search-menu-select")
    codigo_ativo = lista_ativo.find_all("option")

    resultados = []

    for codigos_ativos in codigo_ativo:
        
        resultados.append(codigos_ativos.text.strip()[:6]+".SA")

    return resultados

        

def retornar_detalhes_ativo(ativo):

    nome_empresa_longo, nome_empresa_curto, setor, website, tipo_ativo = "", "", "", "", ""
    
    ativo_ = yf.Ticker(ativo)

    try:
        ativo_.info["longName"]
    except KeyError:
        codigo_ativo = ativo
        ativo_existente = 0
    else:
        codigo_ativo = ativo
        nome_empresa_longo = ativo_.info["shortName"]
        nome_empresa_curto = ativo_.info["longName"]
        
        setor = ativo_.info["sector"]
        ativo_existente = 1
        website = ativo_.info["website"]
        tipo_ativo = "acao"
        if nome_empresa_longo.find("Fundo") > -1: tipo_ativo = "fii"

    return codigo_ativo, nome_empresa_longo, nome_empresa_curto, setor, website, tipo_ativo, ativo_existente


#teste = retornar_acoes_existentes()


def retornar_todos_ativos():

    ...

    return retornar_acoes_existentes(), retornar_fiis_existentes()

# %%
retornar_detalhes_ativo("AERI3.SA")

# %%
import csv
import retornar_ativos as ra

arquivo = open("ativos.csv", "w", newline="")

dados = ra.retornar_acoes_existentes()
#dados = ra.retornar_fiis_existentes()


gravar = csv.writer(arquivo)
for i in dados:
    #print(i)
    gravar.writerow(i)

# %%
with open("ativos.csv", "r", encoding="utf-8") as arquivo_referencia:

    tabela = csv.reader(arquivo_referencia, delimiter=",")

    for l in tabela:
        print(l)

# %%
ra.retornar_fiis_existentes()
# Out:
# ['ABCP11.SA',
#  'AFCR11.SA',
#  'AFHI11.SA',
#  'AFOF11.SA',
#  'AIEC11.SA',
#  'ALMI11.SA',
#  'ALZR11.SA',
#  'ANCR11.SA',
#  'APTO11.SA',
#  'AQLL11.SA',
#  'ARCT11.SA',
#  'ARFI11.SA',
#  'ARRI11.SA',
#  'ATCR11.SA',
#  'ATSA11.SA',
#  'ATWN11.SA',
#  'BARI11.SA',
#  'BBFI11.SA',
#  'BBFO11.SA',
#  'BBIM11.SA',
#  'BBPO11.SA',
#  'BBRC11.SA',
#  'BBVJ11.SA',
#  'BCFF11.SA',
#  'BCIA11.SA',
#  'BCRI11.SA',
#  'BICE11.SA',
#  'BICR11.SA',
#  'BIME11.SA',
#  'BLCA11.SA',
#  'BLCP11.SA',
#  'BLMC11.SA',
#  'BLMG11.SA',
#  'BLMO11.SA',
#  'BLMR11.SA',
#  'BMII11.SA',
#  'BMLC11.SA',
#  'BMLC11.SA',
#  'BNFS11.SA',
#  'BPFF11.SA',
#  'BPML11.SA',
#  'BRCO11.SA',
#  'BRCR11.SA',
#  'BREV11.SA',
#  'BRHT11.SA',
#  'BRIP11.SA',
#  'BRLA11.SA',
#  'BROL11.SA',
#  'BTAL11.SA',
#  'BTCR11.SA',
#  'BTGM11.SA',
#  'BTLG11.SA',
#  'BTRA11.SA',
#  'BTSG11.SA',
#  'BTWR11.SA',
#  'BVAR11.SA',
#  'BZLI11.SA',
#  'CACR11.SA',
#  'CARE11.SA',
#  'CBOP11.SA',
#  'CCRF11.SA',
#  'CEOC11.SA',
#  'CJCT11.SA',
#  'CNES11.SA',
#  'CORM11.SA',
#  'CPFF11.SA',
#  'CPTS11.SA',
#  'CRFF11.SA',
#  'CTXT11.SA',
#  'CVBI11.SA',
#  'CXAG11.SA',
#  'CXCE11.SA',
#  'CXCI11.SA',
#  'CXCO11.SA',
#  'CXRI11.SA',
#  'CXTL11.SA',
#  'CYCR11.SA',
#  'DEVA11.SA',
#  'DMAC11.SA',
#  'DOMC11.SA',
#  'DOVL11.SA',
#  'DRIT11.SA',
#  'DVFF11.SA',
#  'EDFO11.SA',
#  'EDGA11.SA',
#  'EGYR11.SA',
#  'ELDO11.SA',
#  'EQIA11.SA',
#  'EQIN11.SA',
#  'EQIR11.SA',
#  'ERCR11.SA',
#  'ERPA11.SA',
#  'EURO11.SA',
#  'EVBI11.SA',
#  'FAED11.SA',
#  'FAMB11.SA',
#  'FATN11.SA',
#  'FCAS11.SA',
#  'FCFL11.SA',
#  'FEXC11.SA',
#  'FFCI11.SA',
#  'FIGS11.SA',
#  'FIIB11.SA',
#  'FIIP11.SA',
#  'FINF11.SA',
#  'FISC11.SA',
#  'FIVN11.SA',
#  'FLCR11.SA',
#  'FLMA11.SA',
#  'FLRP11.SA',
#  'FMOF11.SA',
#  'FOFT11.SA',
#  'FPAB11.SA',
#  'FPNG11.SA',
#  'FVBI11.SA',
#  'FVPQ11.SA',
#  'GALG11.SA',
#  'GAME11.SA',
#  'GCFF11.SA',
#  'GCRI11.SA',
#  'GESE11.SA',
#  'GGRC11.SA',
#  'GLPL11.SA',
#  'GRLV11.SA',
#  'GSFI11.SA',
#  'GTLG11.SA',
#  'GTWR11.SA',
#  'HAAA11.SA',
#  'HABT11.SA',
#  'HBRH11.SA',
#  'HBTT11.SA',
#  'HCHG11.SA',
#  'HCRI11.SA',
#  'HCST11.SA',
#  'HCTR11.SA',
#  'HFOF11.SA',
#  'HGBS11.SA',
#  'HGCR11.SA',
#  'HGFF11.SA',
#  'HGIC11.SA',
#  'HGLG11.SA',
#  'HGPO11.SA',
#  'HGRE11.SA',
#  'HGRS11.SA',
#  'HGRU11.SA',
#  'HLOG11.SA',
#  'HMOC11.SA',
#  'HOSI11.SA',
#  'HPDP11.SA',
#  'HRDF11.SA',
#  'HREC11.SA',
#  'HSAF11.SA',
#  'HSLG11.SA',
#  'HSML11.SA',
#  'HSRE11.SA',
#  'HTMX11.SA',
#  'HUSC11.SA',
#  'HUSI11.SA',
#  'IBCR11.SA',
#  'IBFF11.SA',
#  'IDFI11.SA',
#  'IFID11.SA',
#  'IFIE11.SA',
#  'IRDM11.SA',
#  'IRIM11.SA',
#  'ITIP11.SA',
#  'ITIT11.SA',
#  'JFLL11.SA',
#  'JGPX11.SA',
#  'JPPA11.SA',
#  'JRDM11.SA',
#  'JSAF11.SA',
#  'JSRE11.SA',
#  'KEVE11.SA',
#  'KFOF11.SA',
#  'KINP11.SA',
#  'KISU11.SA',
#  'KNCR11.SA',
#  'KNHY11.SA',
#  'KNIP11.SA',
#  'KNRE11.SA',
#  'KNRI11.SA',
#  'KNSC11.SA',
#  'LASC11.SA',
#  'LFTT11.SA',
#  'LGCP11.SA',
#  'LUGG11.SA',
#  'LVBI11.SA',
#  'MALL11.SA',
#  'MATV11.SA',
#  'MAXR11.SA',
#  'MBRF11.SA',
#  'MCCI11.SA',
#  'MCFF11.SA',
#  'MCHF11.SA',
#  'MCHY11.SA',
#  'MFAI11.SA',
#  'MFII11.SA',
#  'MFVI11.SA',
#  'MGCR11.SA',
#  'MGFF11.SA',
#  'MGHT11.SA',
#  'MGLG11.SA',
#  'MINT11.SA',
#  'MOFF11.SA',
#  'MORC11.SA',
#  'MORE11.SA',
#  'MTOF11.SA',
#  'MXRF11.SA',
#  'NAVT11.SA',
#  'NCHB11.SA',
#  'NEWL11.SA',
#  'NEWU11.SA',
#  'NSLU11.SA',
#  'NVHO11.SA',
#  'NVIF11.SA',
#  'ONEF11.SA',
#  'ORPD11.SA',
#  'OUFF11.SA',
#  'OUJP11.SA',
#  'OULG11.SA',
#  'OURE11.SA',
#  'PABY11.SA',
#  'PATC11.SA',
#  'PATL11.SA',
#  'PLCR11.SA',
#  'PLOG11.SA',
#  'PLRI11.SA',
#  'PORD11.SA',
#  'PQAG11.SA',
#  'PQDP11.SA',
#  'PRSV11.SA',
#  'PRTS11.SA',
#  'PVBI11.SA',
#  'QAGR11.SA',
#  'QAMI11.SA',
#  'QIFF11.SA',
#  'QIRI11.SA',
#  'QMFF11.SA',
#  'RBBV11.SA',
#  'RBCB11.SA',
#  'RBCO11.SA',
#  'RBDS11.SA',
#  'RBED11.SA',
#  'RBFF11.SA',
#  'RBGS11.SA',
#  'RBHG11.SA',
#  'RBHY11.SA',
#  'RBIR11.SA',
#  'RBIV11.SA',
#  'RBLG11.SA',
#  'RBRD11.SA',
#  'RBRF11.SA',
#  'RBRI11.SA',
#  'RBRL11.SA',
#  'RBRP11.SA',
#  'RBRR11.SA',
#  'RBRS11.SA',
#  'RBRY11.SA',
#  'RBTS11.SA',
#  'RBVA11.SA',
#  'RBVO11.SA',
#  'RCFA11.SA',
#  'RCFF11.SA',
#  'RCRB11.SA',
#  'RDES11.SA',
#  'RDPD11.SA',
#  'RECH11.SA',
#  'RECR11.SA',
#  'RECT11.SA',
#  'RECX11.SA',
#  'RELG11.SA',
#  'RFOF11.SA',
#  'RMAI11.SA',
#  'RNDP11.SA',
#  'RNGO11.SA',
#  'RRCI11.SA',
#  'RSPD11.SA',
#  'RVBI11.SA',
#  'RZAG11.SA',
#  'RZAK11.SA',
#  'RZTR11.SA',
#  'SAAG11.SA',
#  'SADI11.SA',
#  'SAIC11.SA',
#  'SARE11.SA',
#  'SCPF11.SA',
#  'SDIL11.SA',
#  'SDIP11.SA',
#  'SEQR11.SA',
#  'SFND11.SA',
#  'SHDP11.SA',
#  'SHOP11.SA',
#  'SHPH11.SA',
#  'SJAU11.SA',
#  'SNCI11.SA',
#  'SNFF11.SA',
#  'SPTW11.SA',
#  'SPVJ11.SA',
#  'SRVD11.SA',
#  'STRX11.SA',
#  'TBOF11.SA',
#  'TCIN11.SA',
#  'TELD11.SA',
#  'TEPP11.SA',
#  'TGAR11.SA',
#  'THRA11.SA',
#  'TORD11.SA',
#  'TRNT11.SA',
#  'TRXF11.SA',
#  'TRXL11.SA',
#  'UBSR11.SA',
#  'URPR11.SA',
#  'VCJR11.SA',
#  'VCRR11.SA',
#  'VERE11.SA',
#  'VGHF11.SA',
#  'VGIA11.SA',
#  'VGIP11.SA',
#  'VGIR11.SA',
#  'VIFI11.SA',
#  'VILG11.SA',
#  'VINO11.SA',
#  'VISC11.SA',
#  'VIUR11.SA',
#  'VJFD11.SA',
#  'VLOL11.SA',
#  'VOTS11.SA',
#  'VPSI11.SA',
#  'VRTA11.SA',
#  'VSHO11.SA',
#  'VSLH11.SA',
#  'VTLT11.SA',
#  'VTPL11.SA',
#  'VVPR11.SA',
#  'VXXV11.SA',
#  'WPLZ11.SA',
#  'WTSP11.SA',
#  'XPCA11.SA',
#  'XPCI11.SA',
#  'XPCM11.SA',
#  'XPHT11.SA',
#  'XPIN11.SA',
#  'XPLG11.SA',
#  'XPML11.SA',
#  'XPPR11.SA',
#  'XPSF11.SA',
#  'XTED11.SA',
#  'YCHY11.SA',
#  'YUFI11.SA']

# %%
ra.retornar_acoes_existentes()
# Out:
# ['AERI3.SA',
#  'ICBR3.SA',
#  'DOTZ3.SA',
#  'GOLL3.SA',
#  'ARML3.SA',
#  'MLAS3.SA',
#  'CBAV3.SA',
#  'TTEN3.SA',
#  'BRBI11.SA',
#  'NINJ3.SA',
#  'ATEA3.SA',
#  'MODL4.SA',
#  'MODL11.SA',
#  'MODL3.SA',
#  'VITT3.SA',
#  'KRSA3.SA',
#  'CXSE3.SA',
#  'RIOS3.SA',
#  'HCAR3.SA',
#  'GGPS3.SA',
#  'MATD3.SA',
#  'ALLD3.SA',
#  'BLAU3.SA',
#  'ATMP3.SA',
#  'ASAI3.SA',
#  'JSLG3.SA',
#  'CMIN3.SA',
#  'ELMD3.SA',
#  'ORVR3.SA',
#  'OPCT3.SA',
#  'WEST3.SA',
#  'CSED3.SA',
#  'BMOB3.SA',
#  'JALL3.SA',
#  'MBLY3.SA',
#  'ESPA3.SA',
#  'VAMO3.SA',
#  'INTB3.SA',
#  'CJCT11.SA',
#  'BMLC11.SA',
#  'RECR11.SA',
#  'URPR11.SA',
#  'DEVA11.SA',
#  'MFAI11.SA',
#  'NGRD3.SA',
#  'AVLL3.SA',
#  'RRRP3.SA',
#  'ENJU3.SA',
#  'CASH3.SA',
#  'TFCO4.SA',
#  'CONX3.SA',
#  'GMAT3.SA',
#  'SEQL3.SA',
#  'PASS3.SA',
#  'BOAS3.SA',
#  'MELK3.SA',
#  'HBSA3.SA',
#  'CURY3.SA',
#  'PLPL3.SA',
#  'PETZ3.SA',
#  'PGMN3.SA',
#  'LAVV3.SA',
#  'LJQQ3.SA',
#  'DMVF3.SA',
#  'SOMA3.SA',
#  'RIVA3.SA',
#  'AMBP3.SA',
#  'ALPK3.SA',
#  'MTRE3.SA',
#  'MDNE3.SA',
#  'VIIA3.SA',
#  'CEDO4.SA',
#  'CEDO3.SA',
#  'NFLX34.SA',
#  'NIKE34.SA',
#  'MCDC34.SA',
#  'HOME34.SA',
#  'FDMO34.SA',
#  'CMCS34.SA',
#  'RDNI3.SA',
#  'SLED3.SA',
#  'RSID3.SA',
#  'MNDL3.SA',
#  'LEVE3.SA',
#  'CTKA4.SA',
#  'CTKA3.SA',
#  'MYPK3.SA',
#  'GRND3.SA',
#  'LCAM3.SA',
#  'CEAB3.SA',
#  'LLIS3.SA',
#  'CGRA4.SA',
#  'CGRA3.SA',
#  'ESTR4.SA',
#  'ESTR3.SA',
#  'DIRR3.SA',
#  'CTNM4.SA',
#  'CTNM3.SA',
#  'EVEN3.SA',
#  'AMAR3.SA',
#  'MOVI3.SA',
#  'JHSF3.SA',
#  'HBOR3.SA',
#  'PDGR3.SA',
#  'EZTC3.SA',
#  'RENT3.SA',
#  'MRVE3.SA',
#  'MGLU3.SA',
#  'LREN3.SA',
#  'COGN3.SA',
#  'WHRL4.SA',
#  'WHRL3.SA',
#  'TCSA3.SA',
#  'SBUB34.SA',
#  'SMLS3.SA',
#  'SEER3.SA',
#  'SLED4.SA',
#  'HOOT4.SA',
#  'GFSA3.SA',
#  'YDUQ3.SA',
#  'CYRE3.SA',
#  'CVCB3.SA',
#  'SBFG3.SA',
#  'PRVA3.SA',
#  'WALM34.SA',
#  'PEPB34.SA',
#  'COLG34.SA',
#  'COCA34.SA',
#  'AVON34.SA',
#  'SMTO3.SA',
#  'MDIA3.SA',
#  'CAML3.SA',
#  'AGRO3.SA',
#  'BEEF3.SA',
#  'BEEF11.SA',
#  'VIVA3.SA',
#  'CRFB3.SA',
#  'PCAR4.SA',
#  'PCAR3.SA',
#  'NTCO3.SA',
#  'MRFG3.SA',
#  'JBSS3.SA',
#  'PGCO34.SA',
#  'BRFS3.SA',
#  'STOC31.SA',
#  'NUBR33.SA',
#  'IGTI11.SA',
#  'IGTI3.SA',
#  'XPBR31.SA',
#  'TRAD3.SA',
#  'BSLI4.SA',
#  'BSLI3.SA',
#  'BTTL3.SA',
#  'BPAR3.SA',
#  'WFCO34.SA',
#  'VISA34.SA',
#  'MSBR34.SA',
#  'MSCD34.SA',
#  'JPMC34.SA',
#  'HONB34.SA',
#  'GEOO34.SA',
#  'GSGI34.SA',
#  'CTGP34.SA',
#  'BOAC34.SA',
#  'MMMC34.SA',
#  'SCAR3.SA',
#  'LPSB3.SA',
#  'BMGB11.SA',
#  'BMGB4.SA',
#  'IGBR3.SA',
#  'GSHP3.SA',
#  'PSSA3.SA',
#  'CARD3.SA',
#  'BBRK3.SA',
#  'BRPR3.SA',
#  'BRSR6.SA',
#  'BRSR5.SA',
#  'BRSR3.SA',
#  'BIDI3.SA',
#  'BIDI11.SA',
#  'BIDI4.SA',
#  'SANB4.SA',
#  'SANB3.SA',
#  'SANB11.SA',
#  'MULT3.SA',
#  'ITUB4.SA',
#  'ITUB3.SA',
#  'ALSO3.SA',
#  'BMIN3.SA',
#  'MERC4.SA',
#  'LOGG3.SA',
#  'ITSA4.SA',
#  'IRBR3.SA',
#  'PDTC3.SA',
#  'SYNE3.SA',
#  'BBDC4.SA',
#  'BBDC3.SA',
#  'BRML3.SA',
#  'APER3.SA',
#  'BBSE3.SA',
#  'BPAN4.SA',
#  'BBAS3.SA',
#  'BBAS12.SA',
#  'BBAS11.SA',
#  'AXPB34.SA',
#  'LAND3.SA',
#  'DEXP4.SA',
#  'DEXP3.SA',
#  'FCXO34.SA',
#  'PMAM3.SA',
#  'FESA4.SA',
#  'FESA3.SA',
#  'EUCA4.SA',
#  'EUCA3.SA',
#  'SUZB3.SA',
#  'KLBN4.SA',
#  'KLBN3.SA',
#  'KLBN11.SA',
#  'VALE5.SA',
#  'UNIP6.SA',
#  'UNIP5.SA',
#  'UNIP3.SA',
#  'NEMO6.SA',
#  'NEMO5.SA',
#  'NEMO3.SA',
#  'MMXM3.SA',
#  'MMXM11.SA',
#  'GOAU4.SA',
#  'DXCO3.SA',
#  'CSNA3.SA',
#  'BRKM6.SA',
#  'BRKM5.SA',
#  'BRKM3.SA',
#  'BRAP4.SA',
#  'BRAP3.SA',
#  'ARMT34.SA',
#  'GTLG11.SA',
#  'PPLA11.SA',
#  'BTLT39.SA',
#  'BSHY39.SA',
#  'BSHV39.SA',
#  'BIEI39.SA',
#  'BIYT39.SA',
#  'BGOV39.SA',
#  'ALUG11.SA',
#  'WRLD11.SA',
#  'CXAG11.SA',
#  'ROOF11.SA',
#  'JGPX11.SA',
#  'PURB11.SA',
#  'BIME11.SA',
#  'JSAF11.SA',
#  'TELD11.SA',
#  'MORC11.SA',
#  'HUSI11.SA',
#  'CYCR11.SA',
#  'EQIR11.SA',
#  'CACR11.SA',
#  'RZAG11.SA',
#  'PORT3.SA',
#  'GETT11.SA',
#  'GETT4.SA',
#  'GETT3.SA',
#  'BIYE39.SA',
#  'BSCZ39.SA',
#  'BUSA39.SA',
#  'BERU39.SA',
#  'BSOX39.SA',
#  'BFCG39.SA',
#  'BFXH39.SA',
#  'BFTA39.SA',
#  'BKYY39.SA',
#  'BQTC39.SA',
#  'BFDN39.SA',
#  'BFDA39.SA',
#  'BFPI39.SA',
#  'BQQW39.SA',
#  'BFPX39.SA',
#  'BCIR39.SA',
#  'BFDL39.SA',
#  'BFBI39.SA',
#  'BOEF39.SA',
#  'BURT39.SA',
#  'BICL39.SA',
#  'BIXG39.SA',
#  'C2OI34.SA',
#  'S2TO34.SA',
#  'MILA.SA',
#  'CSMO.SA',
#  'YDRO11.SA',
#  'SPXB11.SA',
#  'SMAB11.SA',
#  'W2ST34.SA',
#  'S2QS34.SA',
#  'P2AT34.SA',
#  'G2DD34.SA',
#  'D2AS34.SA',
#  'C2PT34.SA',
#  'BIVW39.SA',
#  'BIVE39.SA',
#  'BCWV39.SA',
#  'A2VL34.SA',
#  'A2MC34.SA',
#  'AFHI11.SA',
#  'HSRE11.SA',
#  'VSEC11.SA',
#  'GRAO3.SA',
#  'USTK11.SA',
#  'AGXY3.SA',
#  'CRPG6.SA',
#  'CRPG5.SA',
#  'CRPG3.SA',
#  'SMFT3.SA',
#  'SOJA3.SA',
#  'Z2NG34.SA',
#  'T2TD34.SA',
#  'T2DH34.SA',
#  'S2UI34.SA',
#  'S2QU34.SA',
#  'S2NW34.SA',
#  'S2HO34.SA',
#  'C2ZR34.SA',
#  'U2ST34.SA',
#  'S2EA34.SA',
#  'P2EN34.SA',
#  'M2PW34.SA',
#  'K2CG34.SA',
#  'D2KN34.SA',
#  'C2ON34.SA',
#  'C2HD34.SA',
#  'B2YN34.SA',
#  'ENMT4.SA',
#  'ENMT3.SA',
#  'AIRB34.SA',
#  'PAGS34.SA',
#  'HBRE3.SA',
#  'VBBR3.SA',
#  'RAIZ4.SA',
#  'RECV3.SA',
#  'SLBG34.SA',
#  'HALI34.SA',
#  'COPH34.SA',
#  'COPH34.SA',
#  'CHVX34.SA',
#  'PRIO3.SA',
#  'OSXB3.SA',
#  'DMMO11.SA',
#  'DMMO3.SA',
#  'RPMG3.SA',
#  'UGPA3.SA',
#  'PETR4.SA',
#  'PETR3.SA',
#  'EXXO34.SA',
#  'ENAT3.SA',
#  'ONCO3.SA',
#  'VVEO3.SA',
#  'PARD3.SA',
#  'BIOM3.SA',
#  'BALM4.SA',
#  'BALM3.SA',
#  'PFIZ34.SA',
#  'MRCK34.SA',
#  'GBIO33.SA',
#  'PNVL3.SA',
#  'AALR3.SA',
#  'ODPV3.SA',
#  'RADL3.SA',
#  'QUAL3.SA',
#  'OFSA3.SA',
#  'JNJB34.SA',
#  'HYPE3.SA',
#  'FLRY3.SA',
#  'BMYB34.SA',
#  'ABTT34.SA',
#  'CLSA3.SA',
#  'LVTC3.SA',
#  'G2DI33.SA',
#  'IFCM3.SA',
#  'GOGL35.SA',
#  'LWSA3.SA',
#  'TOTS3.SA',
#  'XRXB34.SA',
#  'QCOM34.SA',
#  'ORCL34.SA',
#  'MSFT34.SA',
#  'IBMB34.SA',
#  'ITLC34.SA',
#  'HPQB34.SA',
#  'CSCO34.SA',
#  'AAPL34.SA',
#  'LINX3.SA',
#  'POSI3.SA',
#  'EBAY34.SA',
#  'BRIT3.SA',
#  'FIQE3.SA',
#  'DESK3.SA',
#  'VERZ34.SA',
#  'OIBR4.SA',
#  'OIBR.SA',
#  'TIMS3.SA',
#  'VIVT3.SA',
#  'TELB4.SA',
#  'TELB3.SA',
#  'ATTB34.SA',
#  'AURE3.SA',
#  'MEGA3.SA',
#  'CEPE6.SA',
#  'CEPE5.SA',
#  'CEPE3.SA',
#  'CEED4.SA',
#  'CEED3.SA',
#  'EEEL4.SA',
#  'EEEL3.SA',
#  'CASN4.SA',
#  'CASN3.SA',
#  'CEGR3.SA',
#  'CEBR6.SA',
#  'CEBR5.SA',
#  'CEBR3.SA',
#  'RNEW4.SA',
#  'RNEW3.SA',
#  'COCE6.SA',
#  'COCE5.SA',
#  'COCE3.SA',
#  'CLSC4.SA',
#  'CLSC3.SA',
#  'ALUP4.SA',
#  'ALUP3.SA',
#  'ALUP11.SA',
#  'SAPR4.SA',
#  'SAPR3.SA',
#  'SAPR11.SA',
#  'CPRE3.SA',
#  'CPLE6.SA',
#  'CPLE5.SA',
#  'CPLE3.SA',
#  'CPFE3.SA',
#  'CGAS5.SA',
#  'CGAS3.SA',
#  'AESB3.SA',
#  'NEOE3.SA',
#  'TRPL4.SA',
#  'TRPL3.SA',
#  'EGIE3.SA',
#  'TAEE4.SA',
#  'TAEE3.SA',
#  'TAEE11.SA',
#  'SBSP3.SA',
#  'RNEW11.SA',
#  'GEPA4.SA',
#  'GEPA3.SA',
#  'CESP6.SA',
#  'CESP5.SA',
#  'CESP3.SA',
#  'CMIG4.SA',
#  'CMIG3.SA',
#  'AFLT3.SA']
